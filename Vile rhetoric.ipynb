# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score, confusion_matrix, classification_report
from transformers import XLMRobertaTokenizer, XLMRobertaForSequenceClassification, AdamW
from torch.optim import lr_scheduler
from tqdm import tqdm
import random
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import display, HTML
import warnings
warnings.filterwarnings('ignore')

# Set seed for reproducibility
def set_seeds(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True

set_seeds()

# Check if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Define custom dataset class
class HateSpeechDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_length=128):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_length = max_length
        
    def __len__(self):
        return len(self.texts)
    
    def __getitem__(self, idx):
        text = str(self.texts[idx])
        label = self.labels[idx]
        
        encoding = self.tokenizer(
            text,
            add_special_tokens=True,
            max_length=self.max_length,
            padding='max_length',
            truncation=True,
            return_attention_mask=True,
            return_tensors='pt'
        )
        
        return {
            'input_ids': encoding['input_ids'].flatten(),
            'attention_mask': encoding['attention_mask'].flatten(),
            'labels': torch.tensor(label, dtype=torch.long)
        }

# Focal Loss definition
class FocalLoss(nn.Module):
    def __init__(self, gamma=2.0, alpha=None):
        super(FocalLoss, self).__init__()
        self.gamma = gamma
        self.alpha = alpha if alpha is not None else torch.tensor([1.0, 1.0]).to(device)
    
    def forward(self, logits, targets):
        ce_loss = torch.nn.functional.cross_entropy(logits, targets, reduction='none')
        pt = torch.exp(-ce_loss)
        focal_loss = (self.alpha[targets] * (1 - pt) ** self.gamma * ce_loss).mean()
        return focal_loss

# Metrics Visualizer class
class MetricsVisualizer:
    def __init__(self):
        self.train_metrics = []
        self.val_metrics = []

    def add_metrics(self, train_metrics, val_metrics):
        self.train_metrics.append(train_metrics)
        self.val_metrics.append(val_metrics)

    def plot_metrics(self):
        epochs = range(1, len(self.train_metrics) + 1)
        metrics = ['loss', 'accuracy', 'f1', 'precision', 'recall']

        plt.figure(figsize=(15, 10))
        for i, metric in enumerate(metrics, 1):
            plt.subplot(2, 3, i)
            plt.plot(epochs, [m[metric] for m in self.train_metrics], 'b-', label=f'Train {metric}')
            plt.plot(epochs, [m[metric] for m in self.val_metrics], 'r-', label=f'Val {metric}')
            plt.title(f'{metric.capitalize()} over epochs')
            plt.xlabel('Epoch')
            plt.ylabel(metric.capitalize())
            plt.legend()
        plt.tight_layout()
        plt.show()

    def plot_confusion_matrix(self, y_true, y_pred):
        cm = confusion_matrix(y_true, y_pred)
        plt.figure(figsize=(8, 6))
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
        plt.title('Confusion Matrix')
        plt.ylabel('True Label')
        plt.xlabel('Predicted Label')
        plt.show()

# Load and preprocess data
def load_data(file_path):
    data = pd.read_csv(file_path)
    if 'text' not in data.columns or 'label' not in data.columns:
        raise ValueError("Dataset must contain 'text' and 'label' columns")
    data = data.sample(frac=1).reset_index(drop=True)  # Shuffle
    return data

# Training function with early stopping and detailed metrics
def train_model(model, train_loader, val_loader, device, num_epochs=10, accum_steps=2):
    optimizer = AdamW(model.parameters(), lr=3e-5, weight_decay=0.05)
    scheduler = lr_scheduler.CosineAnnealingLR(optimizer, T_max=num_epochs)
    criterion = torch.nn.CrossEntropyLoss(weight=torch.tensor([1.0, 3415/2097]).to(device))
    # criterion = FocalLoss(gamma=2.0, alpha=torch.tensor([1.0, 3415/2097]).to(device))  # Uncomment for focal loss
    metrics_viz = MetricsVisualizer()

    best_val_f1 = 0
    patience = 2
    patience_counter = 0
    best_model_path = "best_model.pt"

    for epoch in range(num_epochs):
        # Training phase
        model.train()
        train_loss = 0
        train_preds, train_labels = [], []
        optimizer.zero_grad()

        for i, batch in enumerate(tqdm(train_loader, desc=f'Epoch {epoch + 1}/{num_epochs} - Training')):
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels'].to(device)

            outputs = model(input_ids=input_ids, attention_mask=attention_mask)
            loss = criterion(outputs.logits, labels) / accum_steps

            loss.backward()
            if (i + 1) % accum_steps == 0:
                torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
                optimizer.step()
                scheduler.step()
                optimizer.zero_grad()

            train_loss += loss.item() * accum_steps
            preds = torch.argmax(outputs.logits, dim=1).cpu().detach().numpy()
            train_preds.extend(preds)
            train_labels.extend(labels.cpu().numpy())

        train_metrics = {
            'loss': train_loss / len(train_loader),
            'accuracy': accuracy_score(train_labels, train_preds),
            'f1': f1_score(train_labels, train_preds, average='macro'),
            'precision': precision_score(train_labels, train_preds, average='macro'),
            'recall': recall_score(train_labels, train_preds, average='macro')
        }

        print(f"\nEpoch {epoch + 1} Training Metrics:")
        for metric, value in train_metrics.items():
            print(f"{metric}: {value:.4f}")

        # Validation phase
        model.eval()
        val_loss = 0
        val_preds, val_labels = [], []

        with torch.no_grad():
            for batch in tqdm(val_loader, desc=f'Epoch {epoch + 1}/{num_epochs} - Validation'):
                input_ids = batch['input_ids'].to(device)
                attention_mask = batch['attention_mask'].to(device)
                labels = batch['labels'].to(device)

                outputs = model(input_ids=input_ids, attention_mask=attention_mask)
                loss = criterion(outputs.logits, labels)

                val_loss += loss.item()
                preds = torch.argmax(outputs.logits, dim=1).cpu().numpy()
                val_preds.extend(preds)
                val_labels.extend(labels.cpu().numpy())

        val_metrics = {
            'loss': val_loss / len(val_loader),
            'accuracy': accuracy_score(val_labels, val_preds),
            'f1': f1_score(val_labels, val_preds, average='macro'),
            'precision': precision_score(val_labels, val_preds, average='macro'),
            'recall': recall_score(val_labels, val_preds, average='macro')
        }

        print(f"\nEpoch {epoch + 1} Validation Metrics:")
        for metric, value in val_metrics.items():
            print(f"{metric}: {value:.4f}")
        print(classification_report(val_labels, val_preds, target_names=['Non-Hate', 'Hate']))

        metrics_viz.add_metrics(train_metrics, val_metrics)

        # Save best model and early stopping
        if val_metrics['f1'] > best_val_f1:
            best_val_f1 = val_metrics['f1']
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'scheduler_state_dict': scheduler.state_dict(),
                'best_f1': best_val_f1,
            }, best_model_path)
            print(f"New best model saved with F1: {best_val_f1:.4f}")
            patience_counter = 0
        else:
            patience_counter += 1
            print(f"No improvement. Patience counter: {patience_counter}/{patience}")
            if patience_counter >= patience:
                print(f'Early stopping after {epoch + 1} epochs')
                break

    metrics_viz.plot_metrics()
    metrics_viz.plot_confusion_matrix(val_labels, val_preds)
    return model

# Prepare data with fallback tokenizer
def prepare_data(train_path, batch_size=16):
    data = load_data(train_path)
    train_data, val_data = train_test_split(data, test_size=0.2, random_state=42, stratify=data['label'])
    
    print(f"Training: {len(train_data)}, Validation: {len(val_data)}")

    try:
        tokenizer = XLMRobertaTokenizer.from_pretrained("Rahul-G/TAM-10epoch-RobertaMul", force_download=False)
        print("Loaded custom tokenizer successfully.")
    except (OSError, ValueError) as e:
        print(f"Error loading custom tokenizer: {e}")
        print("Falling back to base XLM-RoBERTa tokenizer.")
        tokenizer = XLMRobertaTokenizer.from_pretrained("xlm-roberta-base")

    train_dataset = HateSpeechDataset(train_data['text'].values, train_data['label'].values, tokenizer)
    val_dataset = HateSpeechDataset(val_data['text'].values, val_data['label'].values, tokenizer)

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2)
    val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False, num_workers=2)

    return train_loader, val_loader, val_data

# Evaluate model
def evaluate_model(model, val_loader, device):
    model.eval()
    criterion = torch.nn.CrossEntropyLoss(weight=torch.tensor([1.0, 3415/2097]).to(device))
    val_loss = 0
    all_preds, all_labels = [], []

    with torch.no_grad():
        for batch in tqdm(val_loader, desc='Evaluating'):
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels'].to(device)

            outputs = model(input_ids=input_ids, attention_mask=attention_mask)
            loss = criterion(outputs.logits, labels)

            val_loss += loss.item()
            preds = torch.argmax(outputs.logits, dim=1).cpu().numpy()
            all_preds.extend(preds)
            all_labels.extend(labels.cpu().numpy())

    metrics = {
        'loss': val_loss / len(val_loader),
        'accuracy': accuracy_score(all_labels, all_preds),
        'f1': f1_score(all_labels, all_preds, average='macro'),
        'precision': precision_score(all_labels, all_preds, average='macro'),
        'recall': recall_score(all_labels, all_preds, average='macro')
    }

    print("\nValidation Metrics (Final):")
    for metric, value in metrics.items():
        print(f"{metric}: {value:.4f}")

    MetricsVisualizer().plot_confusion_matrix(all_labels, all_preds)
    return metrics, all_preds

# Error analysis
def analyze_errors(df, actual_col='label', pred_col='predictions'):
    incorrect = df[df[actual_col] != df[pred_col]]
    print(f"Total incorrect predictions: {len(incorrect)}")
    display(incorrect.head(10))
    return incorrect

# Main execution
def main():
    train_path = "/kaggle/input/tamilhatespeech/train (1).csv"
    train_loader, val_loader, val_data = prepare_data(train_path)

    # Define label mappings to override checkpoint's invalid id2label
    label2id = {"Non-Hate": 0, "Hate": 1}
    id2label = {0: "Non-Hate", 1: "Hate"}

    try:
        model = XLMRobertaForSequenceClassification.from_pretrained(
            "Rahul-G/TAM-10epoch-RobertaMul",
            num_labels=2,
            problem_type="single_label_classification",
            id2label=id2label,
            label2id=label2id
        ).to(device)
        print("Loaded custom model successfully.")
    except Exception as e:
        print(f"Error loading custom model: {e}")
        print("Falling back to base XLM-RoBERTa model.")
        model = XLMRobertaForSequenceClassification.from_pretrained(
            "xlm-roberta-base",
            num_labels=2,
            problem_type="single_label_classification",
            id2label=id2label,
            label2id=label2id
        ).to(device)

    model = train_model(model, train_loader, val_loader, device, num_epochs=10, accum_steps=2)

    torch.save(model.state_dict(), "tamil_hate_speech_xlm_roberta.pt")
    print("Model saved successfully!")

    # Save tokenizer (using the one from prepare_data or fallback)
    try:
        tokenizer = XLMRobertaTokenizer.from_pretrained("Rahul-G/TAM-10epoch-RobertaMul")
        tokenizer.save_pretrained("./saved_tokenizer")
        print("Tokenizer saved successfully!")
    except Exception as e:
        print(f"Error saving custom tokenizer: {e}")
        tokenizer = XLMRobertaTokenizer.from_pretrained("xlm-roberta-base")
        tokenizer.save_pretrained("./saved_tokenizer")
        print("Saved base tokenizer instead.")

    checkpoint = torch.load('best_model.pt')
    model.load_state_dict(checkpoint['model_state_dict'])
    model.to(device)

    val_metrics, val_preds = evaluate_model(model, val_loader, device)

    val_data['predictions'] = val_preds
    val_data.to_csv("val_predictions.csv", index=False)
    print("Validation predictions saved!")

    incorrect_preds = analyze_errors(val_data)
    incorrect_preds.to_csv("incorrect_predictions.csv", index=False)
    print("Incorrect predictions saved!")

if __name__ == "__main__":
    main()
# Out:
# Using device: cuda
# Training: 4409, Validation: 1103
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'BertTokenizer'.
# The class this function is called from is 'XLMRobertaTokenizer'.
# Error loading custom tokenizer: Unable to load vocabulary from file. Please check that the provided vocabulary is accessible and not corrupted.
# Falling back to base XLM-RoBERTa tokenizer.
# Error loading custom model: invalid literal for int() with base 10: 'NEGATIVE'
# Falling back to base XLM-RoBERTa model.
# model.safetensors:   0%|          | 0.00/1.12G [00:00<?, ?B/s]
# Some weights of XLMRobertaForSequenceClassification were not initialized from the model checkpoint at xlm-roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/10 - Training: 100%|██████████| 276/276 [00:57<00:00,  4.78it/s]
# Epoch 1 Training Metrics:
# loss: 0.6939
# accuracy: 0.5806
# f1: 0.5262
# precision: 0.5349
# recall: 0.5299
# Epoch 1/10 - Validation: 100%|██████████| 69/69 [00:04<00:00, 17.12it/s]
# Epoch 1 Validation Metrics:
# loss: 0.6878
# accuracy: 0.5902
# f1: 0.5749
# precision: 0.5749
# recall: 0.5779
#               precision    recall  f1-score   support
#
#     Non-Hate       0.68      0.63      0.66       683
#         Hate       0.47      0.53      0.49       420
#
#     accuracy                           0.59      1103
#    macro avg       0.57      0.58      0.57      1103
# weighted avg       0.60      0.59      0.59      1103
#
# New best model saved with F1: 0.5749
# Epoch 2/10 - Training: 100%|██████████| 276/276 [00:56<00:00,  4.84it/s]
# Epoch 2 Training Metrics:
# loss: 0.6836
# accuracy: 0.5539
# f1: 0.5471
# precision: 0.5532
# recall: 0.5564
# Epoch 2/10 - Validation: 100%|██████████| 69/69 [00:04<00:00, 17.17it/s]
# Epoch 2 Validation Metrics:
# loss: 0.6478
# accuracy: 0.6129
# f1: 0.6058
# precision: 0.6094
# recall: 0.6159
#               precision    recall  f1-score   support
#
#     Non-Hate       0.73      0.60      0.66       683
#         Hate       0.49      0.63      0.55       420
#
#     accuracy                           0.61      1103
#    macro avg       0.61      0.62      0.61      1103
# weighted avg       0.64      0.61      0.62      1103
#
# New best model saved with F1: 0.6058
# Epoch 3/10 - Training: 100%|██████████| 276/276 [00:56<00:00,  4.84it/s]
# Epoch 3 Training Metrics:
# loss: 0.6738
# accuracy: 0.6108
# f1: 0.5973
# precision: 0.5972
# recall: 0.6014
# Epoch 3/10 - Validation: 100%|██████████| 69/69 [00:04<00:00, 17.08it/s]
# Epoch 3 Validation Metrics:
# loss: 0.6468
# accuracy: 0.6691
# f1: 0.6212
# precision: 0.6452
# recall: 0.6196
#               precision    recall  f1-score   support
#
#     Non-Hate       0.70      0.83      0.76       683
#         Hate       0.59      0.41      0.49       420
#
#     accuracy                           0.67      1103
#    macro avg       0.65      0.62      0.62      1103
# weighted avg       0.66      0.67      0.65      1103
#
# New best model saved with F1: 0.6212
# Epoch 4/10 - Training: 100%|██████████| 276/276 [00:56<00:00,  4.85it/s]
# Epoch 4 Training Metrics:
# loss: 0.6334
# accuracy: 0.6614
# f1: 0.6520
# precision: 0.6520
# recall: 0.6600
# Epoch 4/10 - Validation: 100%|██████████| 69/69 [00:04<00:00, 17.18it/s]
# Epoch 4 Validation Metrics:
# loss: 0.7225
# accuracy: 0.6845
# f1: 0.6119
# precision: 0.6807
# recall: 0.6164
#               precision    recall  f1-score   support
#
#     Non-Hate       0.69      0.90      0.78       683
#         Hate       0.67      0.33      0.44       420
#
#     accuracy                           0.68      1103
#    macro avg       0.68      0.62      0.61      1103
# weighted avg       0.68      0.68      0.65      1103
#
# No improvement. Patience counter: 1/2
# Epoch 5/10 - Training: 100%|██████████| 276/276 [00:57<00:00,  4.84it/s]
# Epoch 5 Training Metrics:
# loss: 0.5798
# accuracy: 0.6974
# f1: 0.6913
# precision: 0.6927
# recall: 0.7040
# Epoch 5/10 - Validation: 100%|██████████| 69/69 [00:04<00:00, 17.14it/s]
# Epoch 5 Validation Metrics:
# loss: 0.7022
# accuracy: 0.6646
# f1: 0.6459
# precision: 0.6453
# recall: 0.6466
#               precision    recall  f1-score   support
#
#     Non-Hate       0.73      0.72      0.73       683
#         Hate       0.56      0.57      0.56       420
#
#     accuracy                           0.66      1103
#    macro avg       0.65      0.65      0.65      1103
# weighted avg       0.67      0.66      0.67      1103
#
# New best model saved with F1: 0.6459
# Epoch 6/10 - Training: 100%|██████████| 276/276 [00:57<00:00,  4.84it/s]
# Epoch 6 Training Metrics:
# loss: 0.5219
# accuracy: 0.7530
# f1: 0.7435
# precision: 0.7407
# recall: 0.7498
# Epoch 6/10 - Validation: 100%|██████████| 69/69 [00:04<00:00, 17.16it/s]
# Epoch 6 Validation Metrics:
# loss: 0.6423
# accuracy: 0.6872
# f1: 0.6733
# precision: 0.6716
# recall: 0.6764
#               precision    recall  f1-score   support
#
#     Non-Hate       0.76      0.72      0.74       683
#         Hate       0.58      0.63      0.61       420
#
#     accuracy                           0.69      1103
#    macro avg       0.67      0.68      0.67      1103
# weighted avg       0.69      0.69      0.69      1103
#
# New best model saved with F1: 0.6733
# Epoch 7/10 - Training: 100%|██████████| 276/276 [00:57<00:00,  4.84it/s]
# Epoch 7 Training Metrics:
# loss: 0.4551
# accuracy: 0.8031
# f1: 0.7952
# precision: 0.7916
# recall: 0.8019
# Epoch 7/10 - Validation: 100%|██████████| 69/69 [00:04<00:00, 17.12it/s]
# Epoch 7 Validation Metrics:
# loss: 0.6874
# accuracy: 0.6845
# f1: 0.6791
# precision: 0.6821
# recall: 0.6930
#               precision    recall  f1-score   support
#
#     Non-Hate       0.80      0.66      0.72       683
#         Hate       0.57      0.73      0.64       420
#
#     accuracy                           0.68      1103
#    macro avg       0.68      0.69      0.68      1103
# weighted avg       0.71      0.68      0.69      1103
#
# New best model saved with F1: 0.6791
# Epoch 8/10 - Training: 100%|██████████| 276/276 [00:56<00:00,  4.84it/s]
# Epoch 8 Training Metrics:
# loss: 0.3614
# accuracy: 0.8528
# f1: 0.8468
# precision: 0.8425
# recall: 0.8544
# Epoch 8/10 - Validation: 100%|██████████| 69/69 [00:04<00:00, 17.13it/s]
# Epoch 8 Validation Metrics:
# loss: 0.6983
# accuracy: 0.7516
# f1: 0.7214
# precision: 0.7446
# recall: 0.7137
#               precision    recall  f1-score   support
#
#     Non-Hate       0.76      0.87      0.81       683
#         Hate       0.73      0.55      0.63       420
#
#     accuracy                           0.75      1103
#    macro avg       0.74      0.71      0.72      1103
# weighted avg       0.75      0.75      0.74      1103
#
# New best model saved with F1: 0.7214
# Epoch 9/10 - Training: 100%|██████████| 276/276 [00:57<00:00,  4.84it/s]
# Epoch 9 Training Metrics:
# loss: 0.2995
# accuracy: 0.8873
# f1: 0.8816
# precision: 0.8785
# recall: 0.8854
# Epoch 9/10 - Validation: 100%|██████████| 69/69 [00:04<00:00, 17.19it/s]
# Epoch 9 Validation Metrics:
# loss: 0.8376
# accuracy: 0.7217
# f1: 0.7007
# precision: 0.7043
# recall: 0.6982
#               precision    recall  f1-score   support
#
#     Non-Hate       0.76      0.80      0.78       683
#         Hate       0.64      0.60      0.62       420
#
#     accuracy                           0.72      1103
#    macro avg       0.70      0.70      0.70      1103
# weighted avg       0.72      0.72      0.72      1103
#
# No improvement. Patience counter: 1/2
# Epoch 10/10 - Training: 100%|██████████| 276/276 [00:57<00:00,  4.83it/s]
# Epoch 10 Training Metrics:
# loss: 0.3195
# accuracy: 0.8716
# f1: 0.8651
# precision: 0.8622
# recall: 0.8687
# Epoch 10/10 - Validation: 100%|██████████| 69/69 [00:04<00:00, 17.07it/s]
# Epoch 10 Validation Metrics:
# loss: 1.2820
# accuracy: 0.7380
# f1: 0.6660
# precision: 0.7972
# recall: 0.6651
#               precision    recall  f1-score   support
#
#     Non-Hate       0.71      0.97      0.82       683
#         Hate       0.88      0.36      0.51       420
#
#     accuracy                           0.74      1103
#    macro avg       0.80      0.67      0.67      1103
# weighted avg       0.78      0.74      0.70      1103
#
# No improvement. Patience counter: 2/2
# Early stopping after 10 epochs
# Model saved successfully!
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'BertTokenizer'.
# The class this function is called from is 'XLMRobertaTokenizer'.
# Error saving custom tokenizer: Unable to load vocabulary from file. Please check that the provided vocabulary is accessible and not corrupted.
# Saved base tokenizer instead.
# Evaluating: 100%|██████████| 69/69 [00:04<00:00, 16.99it/s]
# Validation Metrics (Final):
# loss: 0.6983
# accuracy: 0.7516
# f1: 0.7214
# precision: 0.7446
# recall: 0.7137
# Validation predictions saved!
# Total incorrect predictions: 274
#         id                                               text  label  \
# 1426  2997   India glitz avan moothiram koodikiran ninaikiren      1
# 4845  2339  Life time la ippo tha uripidiya pesuranunga Na...      1
# 1386  7817  Arabu sheikh ku kundi kazhuva kooda teriyadame...      1
# 746   7477  Ennudaiya thaithamilil vantha thenkilaiye vuya...      0
# 5105  5578  அறிவு இருக்கா. பேசுபவன் பேர் முஸ்லிம் பேர். அவ...      1
# 823     68  மீட் இதெல்லாம் ஊழல் தமிழ்நாட்டில் நடக்குது உண்...      1
# 4568  5283  பிகார் இளைஞர்கள் அழகான தேற்றம் இருப்பதானால் அவ...      1
# 1312  1925                  வீடு தந்தவனை செருப்பால அடிக்கனும்      0
# 5143  6506   @vellalarvamsam8039  நீ தப்பா பேசினா நானும் த...      1
# 452   4466   @vikramsk5920  vishyatha sonnale sanghi ah da...      0
#
#       predictions
# 1426            0
# 4845            0
# 1386            0
# 746             1
# 5105            0
# 823             0
# 4568            0
# 1312            1
# 5143            0
# 452             1
# Incorrect predictions saved!
